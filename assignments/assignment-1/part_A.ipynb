# %% [markdown]
# <a href="https://colab.research.google.com/github/sihanma666/eng-ai-agents/blob/main/assignments/assignment-1/part_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pantelis/eng-ai-agents.git
# Out:
# Cloning into 'eng-ai-agents'...
# remote: Enumerating objects: 318, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 318 (delta 67), reused 142 (delta 33), pack-reused 125 (from 2)
# Receiving objects: 100% (318/318), 1.01 MiB | 24.01 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(torch.cuda.current_device())
    print(torch.cuda.device_count())
    print(torch.cuda.get_device_name(0))

device
# Out:
# 0
# 1
# Tesla T4
# device(type='cuda', index=0)
